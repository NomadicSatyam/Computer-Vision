# %%
import cv2

cap=cv2.VideoCapture('D:/HOLLYWOOD/123.mp4')

while(cap.isOpened()):
    ret, frame=cap.read()
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
from matplotlib import pyplot as plt

img=cv2.imread('C:/Users/satya/Pictures/PANJAB TOUR/two.jpg')

plt.imshow(img, cmap='gray', interpolation='bicubic')
#plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
font=cv2.FONT_HERSHEY_SIMPLEX

img=cv2.imread('C:/Users/satya/Pictures/PANJAB TOUR/two.jpg')
cv2.putText(img,'Hello I am Satyam',(10,500),font,1,(255,255,255),2)
cv2.imshow("img",img)
cv2.waitKey(0)

# %%
import cv2
font=cv2.FONT_HERSHEY_SIMPLEX

img=cv2.imread('C:/Users/satya/Pictures/PANJAB TOUR/two.jpg')
cv2.putText(img,'Hello I am Satyam',(10,500),font,1,(255,255,255),5)
cv2.imshow("img",img)
cv2.waitKey(0)

# %%
import cv2
font=cv2.FONT_HERSHEY_SIMPLEX

img=cv2.imread('C:/Users/satya/Pictures/PANJAB TOUR/two.jpg')
cv2.putText(img,'Hello I am Satyam',(50,500),font,1,(255,255,255),2)
cv2.imshow("img",img)
cv2.waitKey(0)

# %%
import cv2
font=cv2.FONT_HERSHEY_SIMPLEX

img=cv2.imread('C:/Users/satya/Pictures/PANJAB TOUR/two.jpg')
cv2.putText(img,'Hello I am Satyam',(50,500),font,1,(255,255,255),2)
cv2.imshow("img",img)
cv2.waitKey(0)

# %%
import cv2
font=cv2.FONT_HERSHEY_SIMPLEX

img=cv2.imread('C:/Users/satya/Pictures/PANJAB TOUR/two.jpg')
cv2.putText(img,'Hello I am Satyam',(50,500),font,1,(255,255,255),2)
cv2.imshow("img",img)
cv2.waitKey(0)

# %%
import cv2
font=cv2.FONT_HERSHEY_SIMPLEX

img=cv2.imread('C:/Users/satya/Pictures/PANJAB TOUR/two.jpg')
cv2.putText(img,'Hello I am Satyam',(50,500),font,1,(255,255,255),2)
cv2.imshow("img",img)
cv2.waitKey(0)

# %%
import cv2
font=cv2.FONT_HERSHEY_SIMPLEX

img=cv2.imread('C:/Users/satya/Pictures/PANJAB TOUR/two.jpg')
cv2.putText(img,'Hello I am Satyam',(10,500),font,1,(255,255,255),2)
cv2.imshow("img",img)
cv2.waitKey(0)

# %%
import cv2
font=cv2.FONT_HERSHEY_SIMPLEX

img=cv2.imread('C:/Users/satya/Pictures/PANJAB TOUR/two.jpg')
cv2.putText(img,'Hello I am Satyam',(50,500),font,5,(255,40,25),2)
cv2.imshow("img",img)
cv2.waitKey(0)

# %%
import cv2
font=cv2.FONT_HERSHEY_SIMPLEX

img=cv2.imread('C:/Users/satya/Pictures/PANJAB TOUR/two.jpg')
cv2.putText(img,'Hello I am Satyam',(50,50),font,5,(255,40,25),2)
cv2.imshow("img",img)
cv2.waitKey(0)

# %%
import cv2
font=cv2.FONT_HERSHEY_SIMPLEX

img=cv2.imread('C:/Users/satya/Pictures/PANJAB TOUR/two.jpg')
cv2.putText(img,'Hello I am Satyam',(50,50),font,5,(255,40,25),5)
cv2.imshow("img",img)
cv2.waitKey(0)

# %%
import cv2


img=cv2.imread('C:/Users/satya/Pictures/PANJAB TOUR/two.jpg')
cv2.imshow("original",img)
cv2.waitKey(0)

r=100.0/img.shape[1]
dim= (100,int(img.shape[0] * r))
resized=cv2.resize(img,dim)
cv2.imshow("resized",resized)
cv2.waitKey(0)

# %%
import cv2


img=cv2.imread('C:/Users/satya/Pictures/PANJAB TOUR/two.jpg')
cv2.imshow("original",img)
cv2.waitKey(0)

# %%
r=100.0/img.shape[1]
dim= (100,int(img.shape[0] * r))
resized=cv2.resize(img,dim)
cv2.imshow("resized",resized)
cv2.waitKey(0)

# %%
import cv2


img=cv2.imread('C:/Users/satya/Pictures/PANJAB TOUR/two.jpg')
cv2.imshow("original",img)
cv2.waitKey(0)

# %%
r=100.0/img.shape[1]
dim= (100,int(img.shape[0] * r))
resized=cv2.resize(img,dim)
cv2.imshow("resized",resized)
cv2.waitKey(0)

# %%
import cv2


img=cv2.imread('C:/Users/satya/Pictures/PANJAB TOUR/two.jpg')
#cv2.imshow("original",img)
cv2.waitKey(0)

r=100.0/img.shape[1]
dim= (100,int(img.shape[0] * r))
resized=cv2.resize(img,dim)
cv2.imshow("resized",resized)
cv2.waitKey(0)

# %%
import cv2


img=cv2.imread('C:/Users/satya/Pictures/PANJAB TOUR/two.jpg')
#cv2.imshow("original",img)
cv2.waitKey(0)

r=100.0/img.shape[1]
dim= (100,int(img.shape[0] * r))
resized=cv2.resize(img,dim)
cv2.imshow("resized",resized)
cv2.waitKey(0)

# %%
import cv2


img=cv2.imread('C:/Users/satya/Pictures/PANJAB TOUR/two.jpg')
cv2.imshow("original",img)
cv2.waitKey(0)

r=100.0/img.shape[1]
dim= (100,int(img.shape[0] * r))
resized=cv2.resize(img,dim)
cv2.imshow("resized",resized)
cv2.waitKey(0)

# %%
import cv2


img=cv2.imread('C:/Users/satya/Pictures/PANJAB TOUR/two.jpg')
#cv2.imshow("original",img)
cv2.waitKey(0)

r=100.0/img.shape[1]
dim= (100,int(img.shape[0] * r))
resized=cv2.resize(img,dim)
cv2.imshow("resized",resized)
cv2.waitKey(0)

# %%
r=100.0/img.shape[1]
dim= (100,int(img.shape[0] * r))
resized=cv2.resize(img,dim)
cv2.imshow("resized",resized)
cv2.waitKey(0)

# %%
import cv2


img=cv2.imread('C:/Users/satya/Pictures/PANJAB TOUR/two.jpg')
cv2.imshow("original",img)
cv2.waitKey(0)

r=100.0/img.shape[1]
dim= (100,int(img.shape[0] * r))
resized=cv2.resize(img,dim)
cv2.imshow("resized",resized)
cv2.waitKey(0)
